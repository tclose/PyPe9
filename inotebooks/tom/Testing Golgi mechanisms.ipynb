# %% [markdown]
# ---Initialise IPython Notebook---

# %%
from utilities.inotebook import *inotebook_init()
# Out:
# Using git revision of k-Brain: f67a835e9699fc2305270d1e4f854d727248ba0e

# %% [markdown]
# ---Testing original vs generated golgi mod files using Sergio's hoc script---

# %% [markdown]
# ---Preporatory tasks

# %% [markdown]
# Clear any files that might be getting confused with previous builds

# %%
clear_output_dir()
# Out:
# No files provided, clearing all files in output directoryRemoved generated_granule_mechanisms.log from output directoryRemoved ncml_generated_granule_hoc.log from output directoryRemoved ncml_generated_granule_hoc.dat from output directoryRemoved fabios_granule_hoc.log from output directoryRemoved single_granule.v from output directoryRemoved single_granule_cell.log from output directoryRemoved fabios_granule_hoc.dat from output directoryRemoved generated_granule_mechanisms.test.dat from output directory-----------------------------------Remaining files in output directory-----------------------------------ellipsoid_test.-----------------------------------

# %% [markdown]
# Checking that hoc scripts are doing the same thing

# %% [markdown]
# ---Using pyNN this time (should be the same as the multi-compartment case)

# %%
bash('single_cell.py xml/test/single_golgi_with_axon.xml --output output/single_golgi_with_axon.v', save_output='output/single_golgi_cell_with_axon.log')
# Out:
# NEURON -- VERSION 7.3 (755:56b2e4fa6248) 2013-01-02Duke, Yale, and the BlueBrain Project -- Copyright 1984-2012See http://www.neuron.yale.edu/credits.htmlAdditional mechanisms from files adexp.mod alphaisyn.mod alphasyn.mod expisyn.mod gap.mod gsfa_grr.mod hh_traub.mod netstim2.mod refrac.mod reset.mod stdwa_guetig.mod stdwa_softlimits.mod stdwa_songabbott.mod stdwa_symm.mod tmgsyn.mod tmisyn.mod vecstim.modWarning: uncaught exception: (specificCapacitance (@ (value "1.0") (units "uF_per_cm2")))Warning: uncaught exception: (reversalPotential (@ (value "132.457934") (units "mV") (species "ca") (segmentG......Warning: uncaught exception: (reversalPotential (@ (value "87.39") (units "mV") (species "na") (segmentGroup ...Warning: uncaught exception: (reversalPotential (@ (value "-84.69") (units "mV") (species "k") (segmentGroup .../home/tclose/git/kbrain/xml/test/ncml/build/neuron/Golgi_Solinas08/installGolgi_Solinas08_CaHVA.mod Golgi_Solinas08_CaLVA.mod Golgi_Solinas08_HCN1.mod Golgi_So
# ...

# %% [markdown]
# ---Using pyNN but without axon

# %%
bash('single_cell.py xml/test/single_golgi_without_axon.xml --output output/single_golgi_without_axon.v', save_output='output/single_golgi_cell_without_axon.log')
# Out:
# NEURON -- VERSION 7.3 (755:56b2e4fa6248) 2013-01-02Duke, Yale, and the BlueBrain Project -- Copyright 1984-2012See http://www.neuron.yale.edu/credits.htmlAdditional mechanisms from files adexp.mod alphaisyn.mod alphasyn.mod expisyn.mod gap.mod gsfa_grr.mod hh_traub.mod netstim2.mod refrac.mod reset.mod stdwa_guetig.mod stdwa_softlimits.mod stdwa_songabbott.mod stdwa_symm.mod tmgsyn.mod tmisyn.mod vecstim.modAdditional mechanisms from files Golgi_Solinas08_CaHVA.mod Golgi_Solinas08_CaLVA.mod Golgi_Solinas08_HCN1.mod Golgi_Solinas08_HCN2.mod Golgi_Solinas08_KA.mod Golgi_Solinas08_KCa.mod Golgi_Solinas08_KM.mod Golgi_Solinas08_KV.mod Golgi_Solinas08_Lkg.mod Golgi_Solinas08_Na.mod Golgi_Solinas08_NaP.mod Golgi_Solinas08_NaR.mod Golgi_Solinas08_SK2.mod Golgi_Solinas08_ca.mod Golgi_Solinas08_ca2.modnumprocs=1Building networkPopulations:Population "Golgis"    Structure   : Line      y: 0.0      x0: 0.0      z: 0.0      dx: 1.0    Local cells : 1    Cell type   : Golgi_Solinas08WithoutAxon  
# ...

# %% [markdown]
# ---Using pyNN but with single compartment

# %%
bash('single_cell.py xml/test/single_golgi_single_compartment.xml --output output/single_golgi_single_compartment.v', save_output='output/single_golgi_cell_single_compartment.log')
# Out:
# NEURON -- VERSION 7.3 (755:56b2e4fa6248) 2013-01-02Duke, Yale, and the BlueBrain Project -- Copyright 1984-2012See http://www.neuron.yale.edu/credits.htmlAdditional mechanisms from files adexp.mod alphaisyn.mod alphasyn.mod expisyn.mod gap.mod gsfa_grr.mod hh_traub.mod netstim2.mod refrac.mod reset.mod stdwa_guetig.mod stdwa_softlimits.mod stdwa_songabbott.mod stdwa_symm.mod tmgsyn.mod tmisyn.mod vecstim.modAdditional mechanisms from files Golgi_Solinas08_CaHVA.mod Golgi_Solinas08_CaLVA.mod Golgi_Solinas08_HCN1.mod Golgi_Solinas08_HCN2.mod Golgi_Solinas08_KA.mod Golgi_Solinas08_KCa.mod Golgi_Solinas08_KM.mod Golgi_Solinas08_KV.mod Golgi_Solinas08_Lkg.mod Golgi_Solinas08_Na.mod Golgi_Solinas08_NaP.mod Golgi_Solinas08_NaR.mod Golgi_Solinas08_SK2.mod Golgi_Solinas08_ca.mod Golgi_Solinas08_ca2.modnumprocs=1Building networkPopulations:Population "Golgis"    Structure   : Line      y: 0.0      x0: 0.0      z: 0.0      dx: 1.0    Local cells : 1    Cell type   : Golgi_Solinas08SingleCompart
# ...

# %% [markdown]
# ---Sergio's hoc script and mod files

# %%
bash('cd external/nemo_testing/neuron/sergios_fabios_golgi; nrnivmodl', silent=True)bash('nrngui external/nemo_testing/neuron/sergios_fabios_golgi/sergios_golgi.hoc', save_output='output/sergios_golgi.log')
# Out:
# NEURON -- VERSION 7.3 (755:56b2e4fa6248) 2013-01-02Duke, Yale, and the BlueBrain Project -- Copyright 1984-2012See http://www.neuron.yale.edu/credits.htmlnrniv: unable to open font "*helvetica-medium-r-normal*--14*", using "fixed"Additional mechanisms from files Golgi_BK.mod Golgi_CALC.mod Golgi_CALC_ca2.mod Golgi_Ca_HVA.mod Golgi_Ca_LVA.mod Golgi_KA.mod Golgi_KM.mod Golgi_KV.mod Golgi_Na.mod Golgi_NaP.mod Golgi_NaR.mod Golgi_SK2.mod Golgi_hcn1.mod Golgi_hcn2.mod Golgi_lkg.mod K_conc.mod Na_conc.mod Synapse.mod	1 soma { nseg=1  L=27  Ra=100	/*location 0 attached to cell 0*/	/* First segment only */	insert morphology { diam=27}	insert capacitance { cm=1}	insert Golgi_BK { Aalpha_c_Golgi_BK=7 Balpha_c_Golgi_BK=0.0015 Kalpha_c_Golgi_BK=-11.765 Abeta_c_Golgi_BK=1 Bbeta_c_Golgi_BK=0.00015 Kbeta_c_Golgi_BK=-11.765 gkbar_Golgi_BK=0.003}	insert Golgi_Ca_HVA { gcabar_Golgi_Ca_HVA=0.00046}	insert Golgi_Ca_LVA { gca2bar_Golgi_Ca_LVA=0.00025 shift_Golgi_Ca_LVA=2 v0_m_inf_Golgi_Ca_LVA=-50 v0_h_in
# ...

# %% [markdown]
# ---Fabio's version (without the axon)

# %%
bash('cd external/nemo_testing/neuron/sergios_fabios_golgi; nrnivmodl', silent=True)bash('nrngui external/nemo_testing/neuron/sergios_fabios_golgi/fabios_golgi.hoc', save_output='output/fabios_golgi.log')
# Out:
# NEURON -- VERSION 7.3 (755:56b2e4fa6248) 2013-01-02Duke, Yale, and the BlueBrain Project -- Copyright 1984-2012See http://www.neuron.yale.edu/credits.htmlnrniv: unable to open font "*helvetica-medium-r-normal*--14*", using "fixed"Additional mechanisms from files Golgi_BK.mod Golgi_CALC.mod Golgi_CALC_ca2.mod Golgi_Ca_HVA.mod Golgi_Ca_LVA.mod Golgi_KA.mod Golgi_KM.mod Golgi_KV.mod Golgi_Na.mod Golgi_NaP.mod Golgi_NaR.mod Golgi_SK2.mod Golgi_hcn1.mod Golgi_hcn2.mod Golgi_lkg.mod K_conc.mod Na_conc.mod Synapse.mod	1 soma { nseg=1  L=27  Ra=100	/*location 0 attached to cell 0*/	/* First segment only */	insert morphology { diam=27}	insert capacitance { cm=1}	insert Golgi_BK { Aalpha_c_Golgi_BK=7 Balpha_c_Golgi_BK=0.0015 Kalpha_c_Golgi_BK=-11.765 Abeta_c_Golgi_BK=1 Bbeta_c_Golgi_BK=0.00015 Kbeta_c_Golgi_BK=-11.765 gkbar_Golgi_BK=0.003}	insert Golgi_Ca_HVA { gcabar_Golgi_Ca_HVA=0.00046}	insert Golgi_Ca_LVA { gca2bar_Golgi_Ca_LVA=0.00025 shift_Golgi_Ca_LVA=2 v0_m_inf_Golgi_Ca_LVA=-50 v0_h_in
# ...

# %% [markdown]
# ---Fabio's hoc script and mod files

# %%
bash('cd external/fabios_network; nrnivmodl', silent=True)bash('nrngui external/fabios_network/fabios_golgi.hoc')
# Out:
# NEURON -- VERSION 7.3 (755:56b2e4fa6248) 2013-01-02Duke, Yale, and the BlueBrain Project -- Copyright 1984-2012See http://www.neuron.yale.edu/credits.htmlnrniv: unable to open font "*helvetica-medium-r-normal*--14*", using "fixed"Additional mechanisms from files GRC_CA.mod GRC_CALC.mod GRC_KA.mod GRC_KCA.mod GRC_KIR.mod GRC_KM.mod GRC_KV.mod GRC_LKG1.mod GRC_LKG2.mod GRC_NA.mod Golgi_BK.mod Golgi_CALC.mod Golgi_CALC_ca2.mod Golgi_Ca_HVA.mod Golgi_Ca_LVA.mod Golgi_KA.mod Golgi_KM.mod Golgi_KV.mod Golgi_Na.mod Golgi_NaP.mod Golgi_NaR.mod Golgi_SK2.mod Golgi_hcn1.mod Golgi_hcn2.mod Golgi_lkg.mod K_conc.mod Na_conc.mod gap.mod	1 soma { nseg=1  L=27  Ra=100	/*location 0 attached to cell 3*/	/* First segment only */	insert morphology { diam=27}	insert capacitance { cm=1}	insert Golgi_lkg { glbar_Golgi_lkg=2.1e-05 el_Golgi_lkg=-55}	insert Golgi_Na { Aalpha_m_Golgi_Na=0.3 Kalpha_m_Golgi_Na=-10 V0alpha_m_Golgi_Na=-25 Abeta_m_Golgi_Na=12 Kbeta_m_Golgi_Na=-18.182 V0beta_m_Golgi_Na=-50 Aalpha_h_
# ...

# %% [markdown]
# ---Generated mod files with hoc script that was modified from Sergio's

# %%
bash('cd xml/test/ncml/build/neuron/Golgi_Solinas08/install; nrnivmodl', silent=True)bash('nrngui external/nemo_testing/neuron/ncml_generated_hoc/ncml_generated_golgi.hoc', save_output='output/ncml_generated_golgi.log')
# Out:
# NEURON -- VERSION 7.3 (755:56b2e4fa6248) 2013-01-02Duke, Yale, and the BlueBrain Project -- Copyright 1984-2012See http://www.neuron.yale.edu/credits.htmlnrniv: unable to open font "*helvetica-medium-r-normal*--14*", using "fixed"Additional mechanisms from files Golgi_Solinas08_CaHVA.mod Golgi_Solinas08_CaLVA.mod Golgi_Solinas08_HCN1.mod Golgi_Solinas08_HCN2.mod Golgi_Solinas08_KA.mod Golgi_Solinas08_KCa.mod Golgi_Solinas08_KM.mod Golgi_Solinas08_KV.mod Golgi_Solinas08_Lkg.mod Golgi_Solinas08_Na.mod Golgi_Solinas08_NaP.mod Golgi_Solinas08_NaR.mod Golgi_Solinas08_SK2.mod Golgi_Solinas08_ca.mod Golgi_Solinas08_ca2.mod	1 soma { nseg=1  L=27  Ra=100	/*location 0 attached to cell 0*/	/* First segment only */	insert morphology { diam=27}	insert capacitance { cm=1}	insert Golgi_Solinas08_ca { comp187_V_t_Golgi_Solinas08_ca=-35 comp189_cao_Golgi_Solinas08_ca=2 comp187_celsius_Golgi_Solinas08_ca=23 comp188_c_Golgi_Solinas08_ca=0.001}	insert Golgi_Solinas08_ca2 { comp206_valence_Golgi_Solinas0
# ...

# %% [markdown]
# ---Sergio's mod files with Sergio's hoc script

# %%
bash('cd external/nemo_testing/neuron/sergios_fabios_golgi; nrnivmodl', silent=True)bash('nrngui external/nemo_testing/neuron/sergios_fabios_golgi/sergios_golgi.hoc', save_output='output/sergios_golgi.log')
# Out:
# NEURON -- VERSION 7.3 (755:56b2e4fa6248) 2013-01-02Duke, Yale, and the BlueBrain Project -- Copyright 1984-2012See http://www.neuron.yale.edu/credits.htmlnrniv: unable to open font "*helvetica-medium-r-normal*--14*", using "fixed"Additional mechanisms from files Golgi_BK.mod Golgi_CALC.mod Golgi_CALC_ca2.mod Golgi_Ca_HVA.mod Golgi_Ca_LVA.mod Golgi_KA.mod Golgi_KM.mod Golgi_KV.mod Golgi_Na.mod Golgi_NaP.mod Golgi_NaR.mod Golgi_SK2.mod Golgi_hcn1.mod Golgi_hcn2.mod Golgi_lkg.mod K_conc.mod Na_conc.mod Synapse.mod	1 soma { nseg=1  L=27  Ra=100	/*location 0 attached to cell 0*/	/* First segment only */	insert morphology { diam=27}	insert capacitance { cm=1}	insert Golgi_BK { Aalpha_c_Golgi_BK=7 Balpha_c_Golgi_BK=0.0015 Kalpha_c_Golgi_BK=-11.765 Abeta_c_Golgi_BK=1 Bbeta_c_Golgi_BK=0.00015 Kbeta_c_Golgi_BK=-11.765 gkbar_Golgi_BK=0.003}	insert Golgi_Ca_HVA { gcabar_Golgi_Ca_HVA=0.00046}	insert Golgi_Ca_LVA { gca2bar_Golgi_Ca_LVA=0.00025 shift_Golgi_Ca_LVA=2 v0_m_inf_Golgi_Ca_LVA=-50 v0_h_in
# ...

# %% [markdown]
# ---Sergio's mod files with Sergio's hoc script but with only a single somatic compartment

# %%
bash('cd external/nemo_testing/neuron/sergios_fabios_golgi; nrnivmodl', silent=True)bash('nrngui external/nemo_testing/neuron/sergios_fabios_golgi/single_compart_sergios_golgi.hoc', save_output='output/single_compart_sergios_golgi.log')
# Out:
# NEURON -- VERSION 7.3 (755:56b2e4fa6248) 2013-01-02Duke, Yale, and the BlueBrain Project -- Copyright 1984-2012See http://www.neuron.yale.edu/credits.htmlnrniv: unable to open font "*helvetica-medium-r-normal*--14*", using "fixed"Additional mechanisms from files Golgi_BK.mod Golgi_CALC.mod Golgi_CALC_ca2.mod Golgi_Ca_HVA.mod Golgi_Ca_LVA.mod Golgi_KA.mod Golgi_KM.mod Golgi_KV.mod Golgi_Na.mod Golgi_NaP.mod Golgi_NaR.mod Golgi_SK2.mod Golgi_hcn1.mod Golgi_hcn2.mod Golgi_lkg.mod K_conc.mod Na_conc.mod Synapse.mod	1 soma { nseg=1  L=27  Ra=100	/*location 0 attached to cell 0*/	/* First segment only */	insert morphology { diam=27}	insert capacitance { cm=1}	insert Golgi_BK { Aalpha_c_Golgi_BK=7 Balpha_c_Golgi_BK=0.0015 Kalpha_c_Golgi_BK=-11.765 Abeta_c_Golgi_BK=1 Bbeta_c_Golgi_BK=0.00015 Kbeta_c_Golgi_BK=-11.765 gkbar_Golgi_BK=0.003}	insert Golgi_Ca_HVA { gcabar_Golgi_Ca_HVA=0.00046}	insert Golgi_Ca_LVA { gca2bar_Golgi_Ca_LVA=0.00025 shift_Golgi_Ca_LVA=2 v0_m_inf_Golgi_Ca_LVA=-50 v0_h_in
# ...

# %% [markdown]
# ---Compare psections between ncml_generated and ivans_generated output

# %%
compare_psections('output/ncml_generated_golgi.log', 'output/single_golgi_cell_single_compartment.log')
# Out:
# 150       ---------    Ref:        comp574_vcbdur_Golgi_Solinas08_NaP    New:        comp574_vcbdur_Golgi_Solinas08_NaP87.39       ---------    Ref:        comp529_e_Golgi_Solinas08_Na, comp575_e_Golgi_Solinas08_NaP, comp614_e_Golgi_Solinas08_NaR, ena    New:        comp529_e_Golgi_Solinas08_Na, comp575_e_Golgi_Solinas08_NaP, comp614_e_Golgi_Solinas08_NaR, ena-84.69       ---------    Ref:        comp354_e_Golgi_Solinas08_KA, comp406_e_Golgi_Solinas08_KCa, comp440_e_Golgi_Solinas08_KM, comp471_e_Golgi_Solinas08_KV, comp507_e_Golgi_Solinas08_SK2, ek    New:        comp354_e_Golgi_Solinas08_KA, comp406_e_Golgi_Solinas08_KCa, comp440_e_Golgi_Solinas08_KM, comp471_e_Golgi_Solinas08_KV, comp507_e_Golgi_Solinas08_SK2, ek0.3       ---------    Ref:        tau1    New:        0.5       ---------    Ref:        tau2    New:        1200       ---------    Ref:            New:        L113       ---------    Ref:            New:        L, L, L250       ---------    Ref:        comp264_vcbdur_Gol
# ...

# %% [markdown]
# ---Psections between generated and sergios original model

# %%
compare_psections('output/single_golgi_cell_with_axon.log', 'output/sergios_golgi.log')
# Out:
# 150       ---------    Ref:            New:        comp574_vcbdur_Golgi_Solinas08_NaP87.39       ---------    Ref:        ena    New:        comp529_e_Golgi_Solinas08_Na, comp575_e_Golgi_Solinas08_NaP, comp614_e_Golgi_Solinas08_NaR, ena-78       ---------    Ref:        v0_h_inf_Golgi_Ca_LVA    New:        -84.69       ---------    Ref:        ek    New:        comp354_e_Golgi_Solinas08_KA, comp406_e_Golgi_Solinas08_KCa, comp440_e_Golgi_Solinas08_KM, comp471_e_Golgi_Solinas08_KV, comp507_e_Golgi_Solinas08_SK2, ek1.3       ---------    Ref:        beta_Golgi_CALC, beta_Golgi_CALC_ca2    New:        -46       ---------    Ref:        v0_tau_h1_Golgi_Ca_LVA    New:        0.3       ---------    Ref:        Aalpha_m_Golgi_Na    New:        tau10.2       ---------    Ref:        d_Golgi_CALC, d_Golgi_CALC_ca2    New:        0.5       ---------    Ref:            New:        tau2-100       ---------    Ref:        v0_tau_m2_Golgi_Ca_LVA    New:        -80       ---------    Ref:        V0a
# ...

# %% [markdown]
# ---Plotting comparison between different scripts or mod files

# %%
activity_plot('output/single_golgi_with_axon.v output/ncml_generated_golgi_hoc.dat --combine')

# %%
activity_plot('output/single_golgi_with_axon.v output/sergios_golgi_hoc.dat --combine')

# %%
activity_plot('output/single_golgi_with_axon.v output/single_golgi_without_axon.v --combine')

# %%
activity_plot('output/single_golgi_without_axon.v output/fabios_golgi_hoc.dat --combine')

# %% [markdown]
# In this case the peak voltage is the same but the firing rate of the generated files is considerably slower, not sure what the problem is

# %% [markdown]
# ---NEST Versions---

# %%
bash('single_cell.py xml/test/single_golgi_with_axon.xml --output output/single_golgi_with_axon_nest.v --simulator nest', save_output='output/single_golgi_cell_with_axon_nest.log')
# Out:
# Return Code: 1           -- N E S T 2 beta --          Neural Simulation Tool  Copyright 1995-2009 The NEST Initiative   Version 2.0-0-rc4 Oct 16 2012 15:44:27This program is provided AS IS and comes withNO WARRANTY. See the file LICENSE for details.Problems or suggestions?  Website     : http://www.nest-initiative.org  Mailing list: nest_user@nest-initiative.orgType 'nest.help()' to find out more about NEST.Error: (caddr) bad argument type: #f	Call history:	failure1234312351	  	dis10224	  	g1274112742	  	nemo-core#nemo-intern	  	symbol->string	  	string-append	  	string->symbol	  	hash-table-ref	  	datatype#invoke-variant-case	  	hash-table-ref	  	nemo-core#nemo:quantity?	  	datatype#invoke-variant-case	  	filter-map	  	nemo-utils#lookup-def	  	def-default431740	  	body429437	  	<--Warning: uncaught exception: (specificCapacitance (@ (value "1.0") (units "uF_per_cm2")))Warning: uncaught exception: (reversalPotential (@ (value "132.457934") (units "mV") (species "ca") (segmentG......
# ...
