# %% [markdown]
# ---Initialise IPython Notebook---

# %%
from utilities.inotebook import *

# %%
inotebook_init()
# Out:
# Using git revision of k-Brain: c0799b8093d911e107450fec6b35f641d3234196

# %% [markdown]
# ---Testing original vs generated golgi mod files using Sergio's hoc script---

# %% [markdown]
# ---Preporatory tasks

# %% [markdown]
# Clear any files that might be getting confused with previous builds

# %%
clear_output_dir()
# Out:
# No files provided, clearing all files in output directoryRemoved fabios_golgi_hoc.dat from output directoryRemoved single_cell.Golgis.ik from output directoryRemoved single_cell.Golgis.ca2i from output directoryRemoved single_cell.Golgis.ica from output directoryRemoved single_cell.Golgis.ina from output directoryRemoved single_cell.Golgis.v from output directoryRemoved single_compart_generated_golgi_hoc.dat from output directoryRemoved mechanisms.test.dat from output directoryRemoved sergios_golgi_hoc.dat from output directoryRemoved single_cell.Golgis.ca2o from output directoryRemoved mechanisms.log from output directoryRemoved single_compart_generated_golgi.log from output directoryRemoved single_compart_sergios_golgi.log from output directoryRemoved generated_golgi_hoc.dat from output directoryRemoved single_cell.Golgis.ica2 from output directoryRemoved single_cell.Golgis.spikes from output directoryRemoved single_cell.Golgis.cai from output directoryRemoved single_cell.log from output directory-----------------------------------Remaining files in output directory----------------------------------------------------------------------

# %% [markdown]
# Checking that hoc scripts are doing the same thing

# %%
diff('external/original_mod/golgi/sergios_golgi.hoc', 'xml/cerebellum/ncml/build/nmodl/generated_golgi.hoc')
# Out:
# *** --- ****************** 1,5 ****  // This is the absolute path on my machine (feel free to add your own as it doesn't hurt)! nrn_load_dll("/home/tclose/kbrain/external/original_mod/golgi/x86_64/.libs/libnrnmech.so")    objref SpikeTrain, netcon, nil  objref exc[78], inh[27], synapses--- 1,5 ----  // This is the absolute path on my machine (feel free to add your own as it doesn't hurt)! nrn_load_dll("/home/tclose/kbrain/xml/cerebellum/ncml/build/nmodl/x86_64/.libs/libnrnmech.so")    objref SpikeTrain, netcon, nil  objref exc[78], inh[27], synapses****************** 14,38 ****      L = 27      Ra = 100 // From Roth&Hausser2000      celsius = 23!     !     insert Golgi_BK!     insert Golgi_Ca_HVA!     insert Golgi_Ca_LVA!     insert Golgi_CALC!     insert Golgi_CALC_ca2!     insert Golgi_hcn1!     insert Golgi_hcn2      insert Golgi_KA      insert Golgi_KM      insert Golgi_KV!     insert Golgi_lkg      insert Golgi_Na      insert Golgi_NaR-     insert Golgi_NaP      insert Golgi_SK2      !     usetable_Golgi_LVA = 0!     usetable_Golgi_HVA = 0      usetable_Golgi_KA = 0      usetable_Golgi_KV = 0      usetable_Golgi_NaR = 0--- 14,38 ----      L = 27      Ra = 100 // From Roth&Hausser2000      celsius = 23! !     insert Golgi_Ca!     insert Golgi_Ca2!     insert Golgi_CaHVA!     insert Golgi_CaLVA!     insert Golgi_HCN1!     insert Golgi_HCN2      insert Golgi_KA+     insert Golgi_KCa      insert Golgi_KM      insert Golgi_KV!     insert Golgi_Lkg      insert Golgi_Na+     insert Golgi_NaP      insert Golgi_NaR      insert Golgi_SK2      !     usetable_GolgiLVA = 0!     usetable_GolgiHVA = 0      usetable_Golgi_KA = 0      usetable_Golgi_KV = 0      usetable_Golgi_NaR = 0****************** 45,52 ****      cai = cai0_ca_ion      ca2i = cai      ca2o = cao!     cai0_Golgi_CALC = cai0_ca_ion!     ca2i0_Golgi_CALC_ca2 = cai0_ca_ion            ena=87.39      ek=-84.69--- 45,52 ----      cai = cai0_ca_ion      ca2i = cai      ca2o = cao!     cai0_Golgi_Ca = cai0_ca_ion!     ca2i0_Golgi_Ca2 = cai0_ca_ion            ena=87.39      ek=-84.69****************** 70,76 ****          Ra = 100          celsius = 23          !         insert Golgi_lkg          for k=0, 25 {              exc[(i*26)+k] = new Synapse(0.5)          }--- 70,76 ----          Ra = 100          celsius = 23          !         insert Golgi_Lkg          for k=0, 25 {              exc[(i*26)+k] = new Synapse(0.5)          }****************** 90,96 ****    L = 1200    Ra = 100    celsius = 23!   insert Golgi_lkg  }  connect axon(0), soma(0)      --- 90,96 ----    L = 1200    Ra = 100    celsius = 23!   insert Golgi_Lkg  }  connect axon(0), soma(0)      ****************** 142,149 ****    objref output_file  output_file = new File()! printf("Writing output to 'output/sergios_golgi_hoc.dat'")! output_file.wopen("output/sergios_golgi_hoc.dat")  for (i=0; i < rec_v.size(); i=i+1) {    output_file.printf("%g %g\n", rec_t.x[i], rec_v.x[i])  }--- 142,149 ----    objref output_file  output_file = new File()! printf("Writing output to 'output/generated_golgi_hoc.dat'")! output_file.wopen("output/generated_golgi_hoc.dat")  for (i=0; i < rec_v.size(); i=i+1) {    output_file.printf("%g %g\n", rec_t.x[i], rec_v.x[i])  }

# %% [markdown]
# ---Sergio's hoc script and mod files

# %%
bash('cd external/original_mod/golgi; nrnivmodl', silent=True)bash('nrngui external/original_mod/golgi/sergios_golgi.hoc')
# Out:
# NEURON -- Release 7.2 (562:42a47463b504) 2011-12-21Duke, Yale, and the BlueBrain Project -- Copyright 1984-2008See http://www.neuron.yale.edu/credits.htmlnrniv: unable to open font "*helvetica-medium-r-normal*--14*", using "fixed"Additional mechanisms from files Golgi_BK.mod Golgi_CALC.mod Golgi_CALC_ca2.mod Golgi_Ca_HVA.mod Golgi_Ca_LVA.mod Golgi_KA.mod Golgi_KM.mod Golgi_KV.mod Golgi_Na.mod Golgi_NaP.mod Golgi_NaR.mod Golgi_SK2.mod Golgi_hcn1.mod Golgi_hcn2.mod Golgi_lkg.mod K_conc.mod Na_conc.mod Synapse.mod	1 soma { nseg=1  L=27  Ra=100	/*location 0 attached to cell 0*/	/* First segment only */	insert morphology { diam=27}	insert capacitance { cm=1}	insert Golgi_BK { Aalpha_c_Golgi_BK=7 Balpha_c_Golgi_BK=0.0015 Kalpha_c_Golgi_BK=-11.765 Abeta_c_Golgi_BK=1 Bbeta_c_Golgi_BK=0.00015 Kbeta_c_Golgi_BK=-11.765 gkbar_Golgi_BK=0.003}	insert Golgi_Ca_HVA { gcabar_Golgi_Ca_HVA=0.00046}	insert Golgi_Ca_LVA { gca2bar_Golgi_Ca_LVA=0.00025 shift_Golgi_Ca_LVA=2 v0_m_inf_Golgi_Ca_LVA=-50 v0_h_inf_Golgi_Ca_LVA=-78 k_m_inf_Golgi_Ca_LVA=-7.4 k_h_inf_Golgi_Ca_LVA=5 C_tau_m_Golgi_Ca_LVA=3 A_tau_m_Golgi_Ca_LVA=1 v0_tau_m1_Golgi_Ca_LVA=-25 v0_tau_m2_Golgi_Ca_LVA=-100 k_tau_m1_Golgi_Ca_LVA=10 k_tau_m2_Golgi_Ca_LVA=-15 C_tau_h_Golgi_Ca_LVA=85 A_tau_h_Golgi_Ca_LVA=1 v0_tau_h1_Golgi_Ca_LVA=-46 v0_tau_h2_Golgi_Ca_LVA=-405 k_tau_h1_Golgi_Ca_LVA=4 k_tau_h2_Golgi_Ca_LVA=-50}	insert Golgi_CALC { d_Golgi_CALC=0.2 cai0_Golgi_CALC=5e-05 beta_Golgi_CALC=1.3}	insert Golgi_CALC_ca2 { d_Golgi_CALC_ca2=0.2 ca2i0_Golgi_CALC_ca2=5e-05 beta_Golgi_CALC_ca2=1.3}	insert ca2_ion {}	insert Golgi_hcn1 { gbar_Golgi_hcn1=5e-05 Erev_Golgi_hcn1=-20}	insert Golgi_hcn2 { gbar_Golgi_hcn2=8e-05 ehcn2_Golgi_hcn2=-20}	insert Golgi_KA { gkbar_Golgi_KA=0.008}	insert Golgi_KM { gkbar_Golgi_KM=0.001}	insert Golgi_KV { gkbar_Golgi_KV=0.032}	insert Golgi_lkg { glbar_Golgi_lkg=2.1e-05 el_Golgi_lkg=-55}	insert Golgi_Na { Aalpha_m_Golgi_Na=0.3 Kalpha_m_Golgi_Na=-10 V0alpha_m_Golgi_Na=-25 Abeta_m_Golgi_Na=12 Kbeta_m_Golgi_Na=-18.182 V0beta_m_Golgi_Na=-50 Aalpha_h_Golgi_Na=0.21 Kalpha_h_Golgi_Na=-3.333 V0alpha_h_Golgi_Na=-50 Abeta_h_Golgi_Na=3 Kbeta_h_Golgi_Na=-5 V0beta_h_Golgi_Na=-17 gnabar_Golgi_Na=0.048}	insert Golgi_NaR { Aalpha_s_Golgi_NaR=-0.00493 V0alpha_s_Golgi_NaR=-4.48754 Kalpha_s_Golgi_NaR=-6.81881 Shiftalpha_s_Golgi_NaR=8e-05 Abeta_s_Golgi_NaR=0.01558 V0beta_s_Golgi_NaR=43.9749 Kbeta_s_Golgi_NaR=0.10818 Shiftbeta_s_Golgi_NaR=0.04752 Aalpha_f_Golgi_NaR=0.31836 V0alpha_f_Golgi_NaR=-80 Kalpha_f_Golgi_NaR=-62.5262 Abeta_f_Golgi_NaR=0.01014 V0beta_f_Golgi_NaR=-83.3332 Kbeta_f_Golgi_NaR=16.0538 gnabar_Golgi_NaR=0.0017}	insert Golgi_NaP { gbar_Golgi_NaP=0.00019}	insert na_ion { ena=87.39}	insert Golgi_SK2 { gkbar_Golgi_SK2=0.038}	insert ca_ion {}	insert k_ion { ek=-84.69}}	1 ena: 87.390000	14 ek: -84.690000	14 eca: 132.457934	15 celsius: 23.000000	18 	1 	1 Writing output to 'output/sergios_golgi_hoc.dat'	48 	1 	0

# %% [markdown]
# ---Fabio's hoc script and mod files

# %%
bash('cd external/fabios_network; nrnivmodl', silent=True)bash('nrngui external/fabios_network/fabios_golgi.hoc')
# Out:
# NEURON -- Release 7.2 (562:42a47463b504) 2011-12-21Duke, Yale, and the BlueBrain Project -- Copyright 1984-2008See http://www.neuron.yale.edu/credits.htmlnrniv: unable to open font "*helvetica-medium-r-normal*--14*", using "fixed"Additional mechanisms from files GRC_CA.mod GRC_CALC.mod GRC_KA.mod GRC_KCA.mod GRC_KIR.mod GRC_KM.mod GRC_KV.mod GRC_LKG1.mod GRC_LKG2.mod GRC_NA.mod Golgi_BK.mod Golgi_CALC.mod Golgi_CALC_ca2.mod Golgi_Ca_HVA.mod Golgi_Ca_LVA.mod Golgi_KA.mod Golgi_KM.mod Golgi_KV.mod Golgi_Na.mod Golgi_NaP.mod Golgi_NaR.mod Golgi_SK2.mod Golgi_hcn1.mod Golgi_hcn2.mod Golgi_lkg.mod K_conc.mod Na_conc.mod gap.mod	1 soma { nseg=1  L=27  Ra=100	/*location 0 attached to cell 3*/	/* First segment only */	insert morphology { diam=27}	insert capacitance { cm=1}	insert Golgi_lkg { glbar_Golgi_lkg=2.1e-05 el_Golgi_lkg=-55}	insert Golgi_Na { Aalpha_m_Golgi_Na=0.3 Kalpha_m_Golgi_Na=-10 V0alpha_m_Golgi_Na=-25 Abeta_m_Golgi_Na=12 Kbeta_m_Golgi_Na=-18.182 V0beta_m_Golgi_Na=-50 Aalpha_h_Golgi_Na=0.21 Kalpha_h_Golgi_Na=-3.333 V0alpha_h_Golgi_Na=-50 Abeta_h_Golgi_Na=3 Kbeta_h_Golgi_Na=-5 V0beta_h_Golgi_Na=-17 gnabar_Golgi_Na=0.048}	insert Golgi_NaR { Aalpha_s_Golgi_NaR=-0.00493 V0alpha_s_Golgi_NaR=-4.48754 Kalpha_s_Golgi_NaR=-6.81881 Shiftalpha_s_Golgi_NaR=8e-05 Abeta_s_Golgi_NaR=0.01558 V0beta_s_Golgi_NaR=43.9749 Kbeta_s_Golgi_NaR=0.10818 Shiftbeta_s_Golgi_NaR=0.04752 Aalpha_f_Golgi_NaR=0.31836 V0alpha_f_Golgi_NaR=-80 Kalpha_f_Golgi_NaR=-62.5262 Abeta_f_Golgi_NaR=0.01014 V0beta_f_Golgi_NaR=-83.3332 Kbeta_f_Golgi_NaR=16.0538 gnabar_Golgi_NaR=0.0017}	insert Golgi_NaP { gbar_Golgi_NaP=0.00019}	insert Golgi_Ca_HVA { gcabar_Golgi_Ca_HVA=0.00046}	insert Golgi_Ca_LVA { gca2bar_Golgi_Ca_LVA=0.00025 shift_Golgi_Ca_LVA=2 v0_m_inf_Golgi_Ca_LVA=-50 v0_h_inf_Golgi_Ca_LVA=-78 k_m_inf_Golgi_Ca_LVA=-7.4 k_h_inf_Golgi_Ca_LVA=5 C_tau_m_Golgi_Ca_LVA=3 A_tau_m_Golgi_Ca_LVA=1 v0_tau_m1_Golgi_Ca_LVA=-25 v0_tau_m2_Golgi_Ca_LVA=-100 k_tau_m1_Golgi_Ca_LVA=10 k_tau_m2_Golgi_Ca_LVA=-15 C_tau_h_Golgi_Ca_LVA=85 A_tau_h_Golgi_Ca_LVA=1 v0_tau_h1_Golgi_Ca_LVA=-46 v0_tau_h2_Golgi_Ca_LVA=-405 k_tau_h1_Golgi_Ca_LVA=4 k_tau_h2_Golgi_Ca_LVA=-50}	insert Golgi_KV { gkbar_Golgi_KV=0.032}	insert Golgi_KM { gkbar_Golgi_KM=0.001}	insert Golgi_KA { gkbar_Golgi_KA=0.008}	insert Golgi_BK { Aalpha_c_Golgi_BK=7 Balpha_c_Golgi_BK=0.0015 Kalpha_c_Golgi_BK=-11.765 Abeta_c_Golgi_BK=1 Bbeta_c_Golgi_BK=0.00015 Kbeta_c_Golgi_BK=-11.765 gkbar_Golgi_BK=0.003}	insert Golgi_SK2 { gkbar_Golgi_SK2=0.038}	insert Golgi_hcn1 { gbar_Golgi_hcn1=5e-05 Erev_Golgi_hcn1=-20}	insert Golgi_hcn2 { gbar_Golgi_hcn2=8e-05 ehcn2_Golgi_hcn2=-20}	insert Golgi_CALC { d_Golgi_CALC=0.2 cai0_Golgi_CALC=5e-05 beta_Golgi_CALC=1.3}	insert ca_ion {}	insert Golgi_CALC_ca2 { d_Golgi_CALC_ca2=0.2 ca2i0_Golgi_CALC_ca2=5e-05 beta_Golgi_CALC_ca2=1.3}	insert ca2_ion {}	insert na_conc { d_na_conc=0.2 nao0_na_conc=145 nai0_na_conc=5 beta_na_conc=0.075}	insert na_ion {}	insert k_conc { d_k_conc=0.2 ko0_k_conc=5 ki0_k_conc=140 beta_k_conc=0.075}	insert k_ion {}	insert Exp2Syn { tau1=0.03 tau2=0.5 e=0}	insert Exp2Syn { tau1=0.03 tau2=0.5 e=0}}	1 ena: 87.390000	14 ek: -84.690000	14 eca: 132.457934	15 celsius: 23.000000	18 	1 	1 Writing output to 'output/fabios_golgi_hoc.dat'	47 	1 	0

# %% [markdown]
# ---Generated mod files with hoc script that was modified from Sergio's

# %%
bash('cd xml/cerebellum/ncml/build/nmodl; nrnivmodl', silent=True)bash('nrngui xml/cerebellum/ncml/build/nmodl/generated_golgi.hoc')
# Out:
# NEURON -- Release 7.2 (562:42a47463b504) 2011-12-21Duke, Yale, and the BlueBrain Project -- Copyright 1984-2008See http://www.neuron.yale.edu/credits.htmlnrniv: unable to open font "*helvetica-medium-r-normal*--14*", using "fixed"Additional mechanisms from files CGC_Ca.mod CGC_CaHVA.mod CGC_KA.mod CGC_KCa.mod CGC_KM.mod CGC_KV.mod CGC_Kir.mod CGC_Lkg1.mod CGC_Lkg2.mod CGC_Na.mod CGC_Nar.mod CGC_pNa.mod Gap.mod Golgi_Ca.mod Golgi_Ca2.mod Golgi_CaHVA.mod Golgi_CaLVA.mod Golgi_HCN1.mod Golgi_HCN2.mod Golgi_KA.mod Golgi_KCa.mod Golgi_KM.mod Golgi_KV.mod Golgi_Lkg.mod Golgi_Na.mod Golgi_NaP.mod Golgi_NaR.mod Golgi_SK2.mod KConc.mod NaConc.mod Synapse.mod old_Golgi_Lkg.mod	1 soma { nseg=1  L=27  Ra=100	/*location 0 attached to cell 0*/	/* First segment only */	insert morphology { diam=27}	insert capacitance { cm=1}	insert Golgi_Ca {}	insert Golgi_Ca2 { comp19_valence_Golgi_Ca2=2}	insert Golgi_CaHVA { comp283_vchdur_Golgi_CaHVA=30 comp19_gbar_Golgi_CaHVA=0.00046 comp283_vchold_Golgi_CaHVA=-71 comp283_vcbase_Golgi_CaHVA=-69 comp19_e_Golgi_CaHVA=129.33 comp283_vcbdur_Golgi_CaHVA=100 comp283_vcsteps_Golgi_CaHVA=8 comp283_vcinc_Golgi_CaHVA=10}	insert Golgi_CaLVA { comp303_vcbase_Golgi_CaLVA=-69 comp19_gbar_Golgi_CaLVA=0.00025 comp303_vchdur_Golgi_CaLVA=200 comp303_vcinc_Golgi_CaLVA=10 comp303_vcsteps_Golgi_CaLVA=8 comp303_vchold_Golgi_CaLVA=-71 comp303_vcbdur_Golgi_CaLVA=30}	insert ca2_ion {}	insert Golgi_HCN1 { comp270_vchdur_Golgi_HCN1=30 comp19_gbar_Golgi_HCN1=5e-05 comp270_vcbdur_Golgi_HCN1=100 comp270_vchold_Golgi_HCN1=-71 comp19_e_Golgi_HCN1=-20 comp270_vcsteps_Golgi_HCN1=8 comp270_vcinc_Golgi_HCN1=10 comp270_vcbase_Golgi_HCN1=-69}	insert Golgi_HCN2 { comp290_vchold_Golgi_HCN2=-71 comp19_gbar_Golgi_HCN2=8e-05 comp290_vcbdur_Golgi_HCN2=100 comp290_vchdur_Golgi_HCN2=30 comp290_vcinc_Golgi_HCN2=10 comp19_e_Golgi_HCN2=-20 comp290_vcsteps_Golgi_HCN2=8 comp290_vcbase_Golgi_HCN2=-69}	insert Golgi_KA { comp35_e_Golgi_KA=-84.69 comp355_vcinc_Golgi_KA=10 comp35_gbar_Golgi_KA=0.008 comp355_vcsteps_Golgi_KA=8 comp355_vchdur_Golgi_KA=30 comp355_vcbdur_Golgi_KA=100 comp355_vchold_Golgi_KA=-71 comp355_vcbase_Golgi_KA=-69}	insert Golgi_KCa { comp170_vcbase_Golgi_KCa=-69 comp170_vchold_Golgi_KCa=-71 comp19_gbar_Golgi_KCa=0.003 comp170_vcbdur_Golgi_KCa=100 comp170_vcinc_Golgi_KCa=10 comp170_vchdur_Golgi_KCa=30 comp19_e_Golgi_KCa=-84.69 comp170_vcsteps_Golgi_KCa=8}	insert Golgi_KM { comp195_vcbase_Golgi_KM=-69 comp195_vcbdur_Golgi_KM=100 comp19_gbar_Golgi_KM=0.001 comp195_vchdur_Golgi_KM=30 comp195_vcsteps_Golgi_KM=8 comp195_vchold_Golgi_KM=-71 comp195_vcinc_Golgi_KM=10 comp19_e_Golgi_KM=-84.69}	insert Golgi_KV { comp183_vcbase_Golgi_KV=-69 comp35_e_Golgi_KV=-84.69 comp183_vcsteps_Golgi_KV=8 comp35_gbar_Golgi_KV=0.032 comp183_vcinc_Golgi_KV=10 comp183_vcbdur_Golgi_KV=100 comp183_vchdur_Golgi_KV=30 comp183_vchold_Golgi_KV=-71}	insert Golgi_Lkg { comp19_gbar_Golgi_Lkg=2.1e-05 comp19_e_Golgi_Lkg=-55}	insert Golgi_Na { comp35_e_Golgi_Na=87.39 comp299_vcsteps_Golgi_Na=9 comp299_vchdur_Golgi_Na=30 comp299_vcbdur_Golgi_Na=100 comp299_vcinc_Golgi_Na=10 comp35_gbar_Golgi_Na=0.048 comp299_vcbase_Golgi_Na=-60 comp299_vchold_Golgi_Na=-71}	insert Golgi_NaP { comp211_vchold_Golgi_NaP=-71 comp35_e_Golgi_NaP=87.39 comp211_vchdur_Golgi_NaP=30 comp211_vcsteps_Golgi_NaP=9 comp35_gbar_Golgi_NaP=0.00019 comp211_vcinc_Golgi_NaP=10 comp211_vcbdur_Golgi_NaP=100 comp211_vcbase_Golgi_NaP=-60}	insert Golgi_NaR { comp313_vchold_Golgi_NaR=-71 comp19_gbar_Golgi_NaR=0.0017 comp313_vchdur_Golgi_NaR=30 comp313_vcsteps_Golgi_NaR=9 comp313_vcbdur_Golgi_NaR=100 comp313_vcbase_Golgi_NaR=-60 comp313_vcinc_Golgi_NaR=10 comp19_e_Golgi_NaR=87.39}	insert na_ion { ena=87.39}	insert Golgi_SK2 { comp220_vchdur_Golgi_SK2=30 comp220_vcinc_Golgi_SK2=10 comp220_vchold_Golgi_SK2=-71 comp19_gbar_Golgi_SK2=0.038 comp220_vcbase_Golgi_SK2=-69 comp220_vcsteps_Golgi_SK2=8 comp220_vcbdur_Golgi_SK2=100 comp19_e_Golgi_SK2=-84.69}	insert k_ion { ek=-84.69}	insert ca_ion {}}	1 ena: 87.390000	14 ek: -84.690000	 ...

# %% [markdown]
# ---Sergio's mod files with Sergio's hoc script but with only a single somatic compartment

# %%
bash('cd external/original_mod/golgi; nrnivmodl', silent=True)bash('nrngui external/original_mod/golgi/single_compart_sergios_golgi.hoc', save_output='output/single_compart_sergios_golgi.log')
# Out:
# NEURON -- Release 7.2 (562:42a47463b504) 2011-12-21Duke, Yale, and the BlueBrain Project -- Copyright 1984-2008See http://www.neuron.yale.edu/credits.htmlnrniv: unable to open font "*helvetica-medium-r-normal*--14*", using "fixed"Additional mechanisms from files Golgi_BK.mod Golgi_CALC.mod Golgi_CALC_ca2.mod Golgi_Ca_HVA.mod Golgi_Ca_LVA.mod Golgi_KA.mod Golgi_KM.mod Golgi_KV.mod Golgi_Na.mod Golgi_NaP.mod Golgi_NaR.mod Golgi_SK2.mod Golgi_hcn1.mod Golgi_hcn2.mod Golgi_lkg.mod K_conc.mod Na_conc.mod Synapse.mod	1 soma { nseg=1  L=27  Ra=100	/*location 0 attached to cell 0*/	/* First segment only */	insert morphology { diam=27}	insert capacitance { cm=1}	insert Golgi_BK { Aalpha_c_Golgi_BK=7 Balpha_c_Golgi_BK=0.0015 Kalpha_c_Golgi_BK=-11.765 Abeta_c_Golgi_BK=1 Bbeta_c_Golgi_BK=0.00015 Kbeta_c_Golgi_BK=-11.765 gkbar_Golgi_BK=0.003}	insert Golgi_Ca_HVA { gcabar_Golgi_Ca_HVA=0.00046}	insert Golgi_Ca_LVA { gca2bar_Golgi_Ca_LVA=0.00025 shift_Golgi_Ca_LVA=2 v0_m_inf_Golgi_Ca_LVA=-50 v0_h_inf_Golgi_Ca_LVA=-78 k_m_inf_Golgi_Ca_LVA=-7.4 k_h_inf_Golgi_Ca_LVA=5 C_tau_m_Golgi_Ca_LVA=3 A_tau_m_Golgi_Ca_LVA=1 v0_tau_m1_Golgi_Ca_LVA=-25 v0_tau_m2_Golgi_Ca_LVA=-100 k_tau_m1_Golgi_Ca_LVA=10 k_tau_m2_Golgi_Ca_LVA=-15 C_tau_h_Golgi_Ca_LVA=85 A_tau_h_Golgi_Ca_LVA=1 v0_tau_h1_Golgi_Ca_LVA=-46 v0_tau_h2_Golgi_Ca_LVA=-405 k_tau_h1_Golgi_Ca_LVA=4 k_tau_h2_Golgi_Ca_LVA=-50}	insert Golgi_CALC { d_Golgi_CALC=0.2 cai0_Golgi_CALC=5e-05 beta_Golgi_CALC=1.3}	insert Golgi_CALC_ca2 { d_Golgi_CALC_ca2=0.2 ca2i0_Golgi_CALC_ca2=5e-05 beta_Golgi_CALC_ca2=1.3}	insert ca2_ion {}	insert Golgi_hcn1 { gbar_Golgi_hcn1=5e-05 Erev_Golgi_hcn1=-20}	insert Golgi_hcn2 { gbar_Golgi_hcn2=8e-05 ehcn2_Golgi_hcn2=-20}	insert Golgi_KA { gkbar_Golgi_KA=0.008}	insert Golgi_KM { gkbar_Golgi_KM=0.001}	insert Golgi_KV { gkbar_Golgi_KV=0.032}	insert Golgi_lkg { glbar_Golgi_lkg=2.1e-05 el_Golgi_lkg=-55}	insert Golgi_Na { Aalpha_m_Golgi_Na=0.3 Kalpha_m_Golgi_Na=-10 V0alpha_m_Golgi_Na=-25 Abeta_m_Golgi_Na=12 Kbeta_m_Golgi_Na=-18.182 V0beta_m_Golgi_Na=-50 Aalpha_h_Golgi_Na=0.21 Kalpha_h_Golgi_Na=-3.333 V0alpha_h_Golgi_Na=-50 Abeta_h_Golgi_Na=3 Kbeta_h_Golgi_Na=-5 V0beta_h_Golgi_Na=-17 gnabar_Golgi_Na=0.048}	insert Golgi_NaR { Aalpha_s_Golgi_NaR=-0.00493 V0alpha_s_Golgi_NaR=-4.48754 Kalpha_s_Golgi_NaR=-6.81881 Shiftalpha_s_Golgi_NaR=8e-05 Abeta_s_Golgi_NaR=0.01558 V0beta_s_Golgi_NaR=43.9749 Kbeta_s_Golgi_NaR=0.10818 Shiftbeta_s_Golgi_NaR=0.04752 Aalpha_f_Golgi_NaR=0.31836 V0alpha_f_Golgi_NaR=-80 Kalpha_f_Golgi_NaR=-62.5262 Abeta_f_Golgi_NaR=0.01014 V0beta_f_Golgi_NaR=-83.3332 Kbeta_f_Golgi_NaR=16.0538 gnabar_Golgi_NaR=0.0017}	insert Golgi_NaP { gbar_Golgi_NaP=0.00019}	insert na_ion { ena=87.39}	insert Golgi_SK2 { gkbar_Golgi_SK2=0.038}	insert ca_ion {}	insert k_ion { ek=-84.69}}	1 ena: 87.390000	14 ek: -84.690000	14 eca: 132.457934	15 celsius: 23.000000	18 	1 	1 Writing output to 'output/single_compart_sergios_golgi_hoc.dat'	63 	1 	0

# %% [markdown]
# ---Generated mod files with hoc script that was modified from Sergio's with only a single somatic compartment

# %%
bash('cd xml/cerebellum/ncml/build/nmodl; nrnivmodl', silent=True)bash('nrngui xml/cerebellum/ncml/build/nmodl/single_compart_generated_golgi.hoc', save_output='output/single_compart_generated_golgi.log')
# Out:
# NEURON -- Release 7.2 (562:42a47463b504) 2011-12-21Duke, Yale, and the BlueBrain Project -- Copyright 1984-2008See http://www.neuron.yale.edu/credits.htmlnrniv: unable to open font "*helvetica-medium-r-normal*--14*", using "fixed"Additional mechanisms from files CGC_Ca.mod CGC_CaHVA.mod CGC_KA.mod CGC_KCa.mod CGC_KM.mod CGC_KV.mod CGC_Kir.mod CGC_Lkg1.mod CGC_Lkg2.mod CGC_Na.mod CGC_Nar.mod CGC_pNa.mod Gap.mod Golgi_Ca.mod Golgi_Ca2.mod Golgi_CaHVA.mod Golgi_CaLVA.mod Golgi_HCN1.mod Golgi_HCN2.mod Golgi_KA.mod Golgi_KCa.mod Golgi_KM.mod Golgi_KV.mod Golgi_Lkg.mod Golgi_Na.mod Golgi_NaP.mod Golgi_NaR.mod Golgi_SK2.mod KConc.mod NaConc.mod Synapse.mod old_Golgi_Lkg.mod	1 soma { nseg=1  L=27  Ra=100	/*location 0 attached to cell 0*/	/* First segment only */	insert morphology { diam=27}	insert capacitance { cm=1}	insert Golgi_Ca {}	insert Golgi_Ca2 { comp19_valence_Golgi_Ca2=2}	insert Golgi_CaHVA { comp283_vchdur_Golgi_CaHVA=30 comp19_gbar_Golgi_CaHVA=0.00046 comp283_vchold_Golgi_CaHVA=-71 comp283_vcbase_Golgi_CaHVA=-69 comp19_e_Golgi_CaHVA=129.33 comp283_vcbdur_Golgi_CaHVA=100 comp283_vcsteps_Golgi_CaHVA=8 comp283_vcinc_Golgi_CaHVA=10}	insert Golgi_CaLVA { comp303_vcbase_Golgi_CaLVA=-69 comp19_gbar_Golgi_CaLVA=0.00025 comp303_vchdur_Golgi_CaLVA=200 comp303_vcinc_Golgi_CaLVA=10 comp303_vcsteps_Golgi_CaLVA=8 comp303_vchold_Golgi_CaLVA=-71 comp303_vcbdur_Golgi_CaLVA=30}	insert ca2_ion {}	insert Golgi_HCN1 { comp270_vchdur_Golgi_HCN1=30 comp19_gbar_Golgi_HCN1=5e-05 comp270_vcbdur_Golgi_HCN1=100 comp270_vchold_Golgi_HCN1=-71 comp19_e_Golgi_HCN1=-20 comp270_vcsteps_Golgi_HCN1=8 comp270_vcinc_Golgi_HCN1=10 comp270_vcbase_Golgi_HCN1=-69}	insert Golgi_HCN2 { comp290_vchold_Golgi_HCN2=-71 comp19_gbar_Golgi_HCN2=8e-05 comp290_vcbdur_Golgi_HCN2=100 comp290_vchdur_Golgi_HCN2=30 comp290_vcinc_Golgi_HCN2=10 comp19_e_Golgi_HCN2=-20 comp290_vcsteps_Golgi_HCN2=8 comp290_vcbase_Golgi_HCN2=-69}	insert Golgi_KA { comp35_e_Golgi_KA=-84.69 comp355_vcinc_Golgi_KA=10 comp35_gbar_Golgi_KA=0.008 comp355_vcsteps_Golgi_KA=8 comp355_vchdur_Golgi_KA=30 comp355_vcbdur_Golgi_KA=100 comp355_vchold_Golgi_KA=-71 comp355_vcbase_Golgi_KA=-69}	insert Golgi_KCa { comp170_vcbase_Golgi_KCa=-69 comp170_vchold_Golgi_KCa=-71 comp19_gbar_Golgi_KCa=0.003 comp170_vcbdur_Golgi_KCa=100 comp170_vcinc_Golgi_KCa=10 comp170_vchdur_Golgi_KCa=30 comp19_e_Golgi_KCa=-84.69 comp170_vcsteps_Golgi_KCa=8}	insert Golgi_KM { comp195_vcbase_Golgi_KM=-69 comp195_vcbdur_Golgi_KM=100 comp19_gbar_Golgi_KM=0.001 comp195_vchdur_Golgi_KM=30 comp195_vcsteps_Golgi_KM=8 comp195_vchold_Golgi_KM=-71 comp195_vcinc_Golgi_KM=10 comp19_e_Golgi_KM=-84.69}	insert Golgi_KV { comp183_vcbase_Golgi_KV=-69 comp35_e_Golgi_KV=-84.69 comp183_vcsteps_Golgi_KV=8 comp35_gbar_Golgi_KV=0.032 comp183_vcinc_Golgi_KV=10 comp183_vcbdur_Golgi_KV=100 comp183_vchdur_Golgi_KV=30 comp183_vchold_Golgi_KV=-71}	insert Golgi_Lkg { comp19_gbar_Golgi_Lkg=2.1e-05 comp19_e_Golgi_Lkg=-55}	insert Golgi_Na { comp35_e_Golgi_Na=87.39 comp299_vcsteps_Golgi_Na=9 comp299_vchdur_Golgi_Na=30 comp299_vcbdur_Golgi_Na=100 comp299_vcinc_Golgi_Na=10 comp35_gbar_Golgi_Na=0.048 comp299_vcbase_Golgi_Na=-60 comp299_vchold_Golgi_Na=-71}	insert Golgi_NaP { comp211_vchold_Golgi_NaP=-71 comp35_e_Golgi_NaP=87.39 comp211_vchdur_Golgi_NaP=30 comp211_vcsteps_Golgi_NaP=9 comp35_gbar_Golgi_NaP=0.00019 comp211_vcinc_Golgi_NaP=10 comp211_vcbdur_Golgi_NaP=100 comp211_vcbase_Golgi_NaP=-60}	insert Golgi_NaR { comp313_vchold_Golgi_NaR=-71 comp19_gbar_Golgi_NaR=0.0017 comp313_vchdur_Golgi_NaR=30 comp313_vcsteps_Golgi_NaR=9 comp313_vcbdur_Golgi_NaR=100 comp313_vcbase_Golgi_NaR=-60 comp313_vcinc_Golgi_NaR=10 comp19_e_Golgi_NaR=87.39}	insert na_ion { ena=87.39}	insert Golgi_SK2 { comp220_vchdur_Golgi_SK2=30 comp220_vcinc_Golgi_SK2=10 comp220_vchold_Golgi_SK2=-71 comp19_gbar_Golgi_SK2=0.038 comp220_vcbase_Golgi_SK2=-69 comp220_vcsteps_Golgi_SK2=8 comp220_vcbdur_Golgi_SK2=100 comp19_e_Golgi_SK2=-84.69}	insert k_ion { ek=-84.69}	insert ca_ion {}}	1 ena: 87.390000	14 ek: -84.690000	 ...

# %% [markdown]
# ---Attempting to replicate results test/mechanisms.py (single compartment)

# %%
bash('mechanisms.py xml/cerebellum/ncml/build/nmodl/Golgi*.mod --init_var ek "-84.69" --init_var ena 87.39 --init_var eca 132.457934 --init_mech_var ca_ion cai0 50e-6 \--init_mech_var ca2_ion ca2i0 50e-6 --init_var cai 50e-6 --init_var ca2i 50e-6 --init_var ca2o 50e-6 --init_mech_var Golgi_Ca cai0 50e-6 --init_mech_var Golgi_Ca2 ca2i0 50e-6 \--length 27 --diam 27 --silent_build --celsius 23 --no_input --no_tables --save_prefix output/mechanisms --timestep 0.025 --no_plot', save_output='output/mechanisms.log')
# Out:
# No current injectedBuild mechanisms in '/home/tclose/git/kbrain/xml/cerebellum/ncml/build/nmodl' directoryBuilding mechanisms in '/home/tclose/git/kbrain/xml/cerebellum/ncml/build/nmodl' directory.NEURON -- Release 7.2 (562:42a47463b504) 2011-12-21Duke, Yale, and the BlueBrain Project -- Copyright 1984-2008See http://www.neuron.yale.edu/credits.htmlAdditional mechanisms from files CGC_Ca.mod CGC_CaHVA.mod CGC_KA.mod CGC_KCa.mod CGC_KM.mod CGC_KV.mod CGC_Kir.mod CGC_Lkg1.mod CGC_Lkg2.mod CGC_Na.mod CGC_Nar.mod CGC_pNa.mod Gap.mod Golgi_Ca.mod Golgi_Ca2.mod Golgi_CaHVA.mod Golgi_CaLVA.mod Golgi_HCN1.mod Golgi_HCN2.mod Golgi_KA.mod Golgi_KCa.mod Golgi_KM.mod Golgi_KV.mod Golgi_Lkg.mod Golgi_Na.mod Golgi_NaP.mod Golgi_NaR.mod Golgi_SK2.mod KConc.mod NaConc.mod Synapse.mod old_Golgi_Lkg.modMechanisms inserted into test: Golgi_Ca, Golgi_Ca2, Golgi_CaHVA, Golgi_CaLVA, Golgi_HCN1, Golgi_HCN2, Golgi_KA, Golgi_KCa, Golgi_KM, Golgi_KV, Golgi_Lkg, Golgi_Na, Golgi_NaP, Golgi_NaR, Golgi_SK2MPI_Initialized==false, disabling MPI functionality.Creating test cell...ek = -84.69ena = 87.39eca = 132.457934cai = 50e-6ca2i = 50e-6ca2o = 50e-6cai0_ca_ion = 50e-6ca2i0_ca2_ion = 50e-6cai0_Golgi_Ca = 50e-6ca2i0_Golgi_Ca2 = 50e-6Starting simulation of 'test'...Simulating at 23.000000CFinished simulation of 'test'Saved test recording to 'output/mechanisms.test.dat'Description of test cell:<__main__.NeuronTestCell object at 0x132aa50>.PySec_28e3b40 { nseg=1  L=27  Ra=100	/*location 0 attached to cell 0*/	/* First segment only */	insert morphology { diam=27}	insert capacitance { cm=1}	insert Golgi_Ca {}	insert Golgi_Ca2 { comp19_valence_Golgi_Ca2=2}	insert Golgi_CaHVA { comp283_vchdur_Golgi_CaHVA=30 comp19_gbar_Golgi_CaHVA=0.00046 comp283_vchold_Golgi_CaHVA=-71 comp283_vcbase_Golgi_CaHVA=-69 comp19_e_Golgi_CaHVA=129.33 comp283_vcbdur_Golgi_CaHVA=100 comp283_vcsteps_Golgi_CaHVA=8 comp283_vcinc_Golgi_CaHVA=10}	insert Golgi_CaLVA { comp303_vcbase_Golgi_CaLVA=-69 comp19_gbar_Golgi_CaLVA=0.00025 comp303_vchdur_Golgi_CaLVA=200 comp303_vcinc_Golgi_CaLVA=10 comp303_vcsteps_Golgi_CaLVA=8 comp303_vchold_Golgi_CaLVA=-71 comp303_vcbdur_Golgi_CaLVA=30}	insert ca2_ion {}	insert Golgi_HCN1 { comp270_vchdur_Golgi_HCN1=30 comp19_gbar_Golgi_HCN1=5e-05 comp270_vcbdur_Golgi_HCN1=100 comp270_vchold_Golgi_HCN1=-71 comp19_e_Golgi_HCN1=-20 comp270_vcsteps_Golgi_HCN1=8 comp270_vcinc_Golgi_HCN1=10 comp270_vcbase_Golgi_HCN1=-69}	insert Golgi_HCN2 { comp290_vchold_Golgi_HCN2=-71 comp19_gbar_Golgi_HCN2=8e-05 comp290_vcbdur_Golgi_HCN2=100 comp290_vchdur_Golgi_HCN2=30 comp290_vcinc_Golgi_HCN2=10 comp19_e_Golgi_HCN2=-20 comp290_vcsteps_Golgi_HCN2=8 comp290_vcbase_Golgi_HCN2=-69}	insert Golgi_KA { comp35_e_Golgi_KA=-84.69 comp355_vcinc_Golgi_KA=10 comp35_gbar_Golgi_KA=0.008 comp355_vcsteps_Golgi_KA=8 comp355_vchdur_Golgi_KA=30 comp355_vcbdur_Golgi_KA=100 comp355_vchold_Golgi_KA=-71 comp355_vcbase_Golgi_KA=-69}	insert Golgi_KCa { comp170_vcbase_Golgi_KCa=-69 comp170_vchold_Golgi_KCa=-71 comp19_gbar_Golgi_KCa=0.003 comp170_vcbdur_Golgi_KCa=100 comp170_vcinc_Golgi_KCa=10 comp170_vchdur_Golgi_KCa=30 comp19_e_Golgi_KCa=-84.69 comp170_vcsteps_Golgi_KCa=8}	insert Golgi_KM { comp195_vcbase_Golgi_KM=-69 comp195_vcbdur_Golgi_KM=100 comp19_gbar_Golgi_KM=0.001 comp195_vchdur_Golgi_KM=30 comp195_vcsteps_Golgi_KM=8 comp195_vchold_Golgi_KM=-71 comp195_vcinc_Golgi_KM=10 comp19_e_Golgi_KM=-84.69}	insert Golgi_KV { comp183_vcbase_Golgi_KV=-69 comp35_e_Golgi_KV=-84.69 comp183_vcsteps_Golgi_KV=8 comp35_gbar_Golgi_KV=0.032 comp183_vcinc_Golgi_KV=10 comp183_vcbdur_Golgi_KV=100 comp183_vchdur_Golgi_KV=30 comp183_vchold_Golgi_KV=-71}	insert Golgi_Lkg { comp19_gbar_Golgi_Lkg=2.1e-05 comp19_e_Golgi_Lkg=-55}	insert Golgi_Na { comp35_e_Golgi_Na=87.39 comp299_vcsteps_Golgi_Na=9 comp299_vchdur_Golgi_Na=30 comp299_vcbdur_Golgi_Na=100 comp299_vcinc_Golgi_Na=10 comp35_gbar_Golgi_Na=0.048 comp299_vcbase_Golgi_Na=-60 comp299_vchold_Golgi_Na=-71}	insert Golgi_NaP { comp211_vchold_Golgi_NaP=-71 comp35_e_Golgi_NaP=87.39 comp21 ...

# %% [markdown]
# ---Using pyNN this time (should be the same as the multi-compartment case)

# %%
bash('single_cell.py xml/cerebellum/single_golgi.xml --silent_build --print_all', save_output='output/single_cell.log')
# Out:
# NEURON -- Release 7.2 (562:42a47463b504) 2011-12-21Duke, Yale, and the BlueBrain Project -- Copyright 1984-2008See http://www.neuron.yale.edu/credits.htmlAdditional mechanisms from files adexp.mod alphaisyn.mod alphasyn.mod expisyn.mod gsfa_grr.mod hh_traub.mod netstim2.mod refrac.mod reset.mod stdwa_guetig.mod stdwa_softlimits.mod stdwa_songabbott.mod stdwa_symm.mod tmgsyn.mod tmisyn.mod vecstim.modAdditional mechanisms from files CGC_Ca.mod CGC_CaHVA.mod CGC_KA.mod CGC_KCa.mod CGC_KM.mod CGC_KV.mod CGC_Kir.mod CGC_Lkg1.mod CGC_Lkg2.mod CGC_Na.mod CGC_Nar.mod CGC_pNa.mod Gap.mod Golgi_Ca.mod Golgi_Ca2.mod Golgi_CaHVA.mod Golgi_CaLVA.mod Golgi_HCN1.mod Golgi_HCN2.mod Golgi_KA.mod Golgi_KCa.mod Golgi_KM.mod Golgi_KV.mod Golgi_Lkg.mod Golgi_Na.mod Golgi_NaP.mod Golgi_NaR.mod Golgi_SK2.mod KConc.mod NaConc.mod Synapse.mod old_Golgi_Lkg.modMPI_Initialized==false, disabling MPI functionality.Building mechanisms in '/home/tclose/git/kbrain/src/pyNN/neuron/nmodl' directory.Building networkBuilding mechanisms in 'xml/cerebellum/./ncml/build/nmodl' directory.ID: axon_0PySec_3e82110 { nseg=1  L=12  Ra=100	PySec_3e7c530 connect PySec_3e82110 (0), 0.5	/* First segment only */	insert morphology { diam=2.4}	insert capacitance { cm=1}	insert Golgi_Lkg { comp19_gbar_Golgi_Lkg=2.1e-05 comp19_e_Golgi_Lkg=-55}}ID: axon_1PySec_3e82170 { nseg=1  L=12  Ra=100	PySec_3e82110 connect PySec_3e82170 (0), 1	/* First segment only */	insert morphology { diam=2.4}	insert capacitance { cm=1}	insert Golgi_Lkg { comp19_gbar_Golgi_Lkg=2.1e-05 comp19_e_Golgi_Lkg=-55}}ID: axon_10PySec_3e824d0 { nseg=1  L=12  Ra=100	PySec_3e82470 connect PySec_3e824d0 (0), 1	/* First segment only */	insert morphology { diam=2.4}	insert capacitance { cm=1}	insert Golgi_Lkg { comp19_gbar_Golgi_Lkg=2.1e-05 comp19_e_Golgi_Lkg=-55}}ID: axon_11PySec_3e82530 { nseg=1  L=12  Ra=100	PySec_3e824d0 connect PySec_3e82530 (0), 1	/* First segment only */	insert morphology { diam=2.4}	insert capacitance { cm=1}	insert Golgi_Lkg { comp19_gbar_Golgi_Lkg=2.1e-05 comp19_e_Golgi_Lkg=-55}}ID: axon_12PySec_3e82590 { nseg=1  L=12  Ra=100	PySec_3e82530 connect PySec_3e82590 (0), 1	/* First segment only */	insert morphology { diam=2.4}	insert capacitance { cm=1}	insert Golgi_Lkg { comp19_gbar_Golgi_Lkg=2.1e-05 comp19_e_Golgi_Lkg=-55}}ID: axon_13PySec_3e825f0 { nseg=1  L=12  Ra=100	PySec_3e82590 connect PySec_3e825f0 (0), 1	/* First segment only */	insert morphology { diam=2.4}	insert capacitance { cm=1}	insert Golgi_Lkg { comp19_gbar_Golgi_Lkg=2.1e-05 comp19_e_Golgi_Lkg=-55}}ID: axon_14PySec_3e82650 { nseg=1  L=12  Ra=100	PySec_3e825f0 connect PySec_3e82650 (0), 1	/* First segment only */	insert morphology { diam=2.4}	insert capacitance { cm=1}	insert Golgi_Lkg { comp19_gbar_Golgi_Lkg=2.1e-05 comp19_e_Golgi_Lkg=-55}}ID: axon_15PySec_3e826b0 { nseg=1  L=12  Ra=100	PySec_3e82650 connect PySec_3e826b0 (0), 1	/* First segment only */	insert morphology { diam=2.4}	insert capacitance { cm=1}	insert Golgi_Lkg { comp19_gbar_Golgi_Lkg=2.1e-05 comp19_e_Golgi_Lkg=-55}}ID: axon_16PySec_3e82710 { nseg=1  L=12  Ra=100	PySec_3e826b0 connect PySec_3e82710 (0), 1	/* First segment only */	insert morphology { diam=2.4}	insert capacitance { cm=1}	insert Golgi_Lkg { comp19_gbar_Golgi_Lkg=2.1e-05 comp19_e_Golgi_Lkg=-55}}ID: axon_17PySec_3e82770 { nseg=1  L=12  Ra=100	PySec_3e82710 connect PySec_3e82770 (0), 1	/* First segment only */	insert morphology { diam=2.4}	insert capacitance { cm=1}	insert Golgi_Lkg { comp19_gbar_Golgi_Lkg=2.1e-05 comp19_e_Golgi_Lkg=-55}}ID: axon_18PySec_3e827d0 { nseg=1  L=12  Ra=100	PySec_3e82770 connect PySec_3e827d0 (0), 1	/* First segment only */	insert morphology { diam=2.4}	insert capacitance { cm=1}	insert Golgi_Lkg { comp19_gbar_Golgi_Lkg=2.1e-05 comp19_e_Golgi_Lkg=-55}}ID: axon_19PySec_3e82830 { nseg=1  L=12  Ra=100	PySec_3e827d0 connect PySec_3e82830 (0), 1	/* First segment only */	insert morphology { diam=2.4}	insert capacitance { cm=1}	insert Golgi_Lkg { comp19_gbar_Golgi_Lkg=2.1e-05 comp19 ...

# %% [markdown]
# ---Plotting comparison between different scripts or mod files

# %%
activity_plot('output/sergios_golgi_hoc.dat output/fabios_golgi_hoc.dat output/generated_golgi_hoc.dat output/single_compart_sergios_golgi_hoc.dat output/single_compart_generated_golgi_hoc.dat output/single_cell.Golgis.v --combine')

# %%
activity_plot('output/sergios_golgi_hoc.dat output/fabios_golgi_hoc.dat --combine')

# %% [markdown]
# In this case the peak voltage is the same but the firing rate of the generated files is considerably slower, not sure what the problem is

# %%
os.listdir('output')

# %%
diff('output/mechanisms.log', 'output/single_compart_generated_golgi.log')

# %%
diff('output/mechanisms.log', 'output/single_cell.log')
